# %% [markdown]
# ### Run the Database Connection File

# %%
# %run ./db_connections.ipynb

# %% [markdown]
# ### Running the ETL and Visualisations for all four datasets

# %%
# %run ./x22163549_Ashlyn_fda_extraction_preprocessing_visualization_loading.ipynb
# Out:
# The connection has been established successfully
# Existing Collection dropped successfully.
# Loading data from FDA API...
# Data loaded successfully from FDA API.
# Data loaded from MongoDB collection into a DataFrame.
# Null Value Count before pre-processing:
# _id                               0
# country                           0
# city                              0
# address_1                         2
# reason_for_recall                 0
# address_2                     22405
# product_quantity               1618
# code_info                        22
# center_classification_date        1
# distribution_pattern              0
# state                           314
# product_description               0
# report_date                       0
# classification                    0
# openfda                           0
# recalling_firm                    0
# recall_number                     1
# initial_firm_notification         7
# product_type                      0
# event_id                          0
# more_code_info                23787
# recall_initiation_date            0
# postal_code                     328
# voluntary_mandated                6
# status                            0
# termination_date               1588
# dtype: int64
# Null Value Count after pre-processing:
# country                       0
# city                          0
# address_1                     0
# reason_for_recall             0
# product_quantity              0
# code_info                     0
# center_classification_date    0
# distribution_pattern          0
# state                         0
# product_description           0
# report_date                   0
# classification                0
# recalling_firm                0
# recall_number                 0
# initial_firm_notification     0
# product_type                  0
# event_id                      0
# recall_initiation_date        1
# postal_code                   0
# voluntary_mandated            0
# status                        0
# termination_date              0
# recall_number_digits          0
# dtype: int64
# Table created successfully!
# Data loaded to PostgreSQL successfully!
# Data loaded from PostgreSQL to DataFrame successfully!

# %%
# %run ./x22162933_Subash_FoodInspection_extraction_preprocessing_visualization_loading_code.ipynb
# Out:
# The connection has been established successfully
# Existing Collection dropped successfully.
# Loading data from JSON file...
# Loaded 26544 records into MongoDB
# Data loaded successfully from JSON file.
# Data loaded into a DataFrame.
# Number of rows before removing duplicates: 22466
# Number of columns before removing duplicates: 10
# Number of rows after removing duplicates: 10055
# Number of columns after removing duplicates: 10
# Number of duplicates in the dataset:  0
# Total number of missing values: 0
# There are 0 invalid values in the dataset.
#                          identification                        name  \
# 3      00500D38A7B20EF985257D77007137C6            Bowl'd(INACTIVE)
# 7      00500D38A7B20EF985257D77007137C6            Bowl'd(INACTIVE)
# 11     00500D38A7B20EF985257D77007137C6            Bowl'd(INACTIVE)
# 14     00754EF78961359F8525789D0052B055    Super Giant Bakery #0774
# 16     00754EF78961359F8525789D0052B055    Super Giant Bakery #0774
# ...                                 ...                         ...
# 26539  FFF57CF7B7A991D885256C25005D5C73  Subway Sandwiches & Salads
# 26540  FFF57CF7B7A991D885256C25005D5C73  Subway Sandwiches & Salads
# 26541  FFF57CF7B7A991D885256C25005D5C73  Subway Sandwiches & Salads
# 26542  FFF57CF7B7A991D885256C25005D5C73  Subway Sandwiches & Salads
# 26543  FFF57CF7B7A991D885256C25005D5C73  Subway Sandwiches & Salads
#
#             status                        type          ranking address  \
# 3      Surrendered        Fast Food Restaurant  Risk Category 3    1028
# 7      Surrendered        Fast Food Restaurant  Risk Category 3    1028
# 11     Surrendered        Fast Food Restaurant  Risk Category 3    1028
# 14       Permitted  Grocery Store Food Service  Risk Category 1    2515
# 16       Permitted  Grocery Store Food Service  Risk Category 1    2515
# ...            ...                         ...              ...     ...
# 26539    Permitted        Fast Food Restaurant  Risk Category 1     801
# 26540    Permitted        Fast Food Restaurant  Risk Category 1     801
# 26541    Permitted        Fast Food Restaurant  Risk Category 1     801
# 26542    Permitted        Fast Food Restaurant  Risk Category 1     801
# 26543    Permitted        Fast Food Restaurant  Risk Category 1     801
#
#             city state                   date             critical
# 3      Arlington    VA  3/29/2017 12:00:00 AM                 Core
# 7      Arlington    VA   4/4/2016 12:00:00 AM                 Core
# 11     Arlington    VA  12/1/2016 12:00:00 AM             Priority
# 14     Arlington    VA  4/18/2018 12:00:00 AM                 Core
# 16     Arlington    VA  4/18/2018 12:00:00 AM  Priority Foundation
# ...          ...   ...                    ...                  ...
# 26539  Arlington    VA   2/1/2018 12:00:00 AM             Priority
# 26540  Arlington    VA   2/6/2017 12:00:00 AM                 Core
# 26541  Arlington    VA   2/6/2017 12:00:00 AM             Priority
# 26542  Arlington    VA   2/6/2017 12:00:00 AM  Priority Foundation
# 26543  Arlington    VA   2/5/2016 12:00:00 AM                 Core
#
# [10055 rows x 10 columns]
# Table created successfully!
# Data loaded to PostgreSQL successfully!
# Data loaded from PostgreSQL to DataFrame successfully!

# %%
# %run ./x22153209_Manoj_nutrients_preprocessing_visualisation_loading.ipynb
# Out:
# Table created successfully!
# Data loaded to PostgreSQL successfully!
# Data loaded from PostgreSQL to DataFrame successfully!

# %%
# %run ./x22142258_Preetham_Disease_Outbreak_PreProcessing_Loading_Visualization.ipynb
# Out:
# Table created successfully!
# Data loaded to PostgreSQL successfully!
# Data loaded from PostgreSQL to DataFrame successfully!

# %%
conn.close()

# %% [markdown]
# ### Merging the Disease Outbreak, Food Inspection and Nutrients Datasets

# %%
result = pd.concat([disease_df_cleaned, FoodInspection_df, nutrients_postgres_df], axis=1)

merged_column_names = list(disease_df_cleaned.columns) + list(FoodInspection_df.columns) + list(nutrients_postgres_df.columns) 
result.to_csv('food data merged.csv', index=False, header=merged_column_names)

df_merged = pd.read_csv('food data merged.csv')
food_analysis_merged = df_merged.head(1000)

# %% [markdown]
# #### Visualization: How do hospitalization rates vary by states and risk category, and how do these trends compare across different states?

# %%
# Group the data by illness state and risk category, and calculate the hospitalization rate
grouped_df = food_analysis_merged.groupby(['state', 'ranking'])['hospitalizations'].mean().unstack()

# Plot the stacked bar chart
grouped_df.plot(kind='bar', stacked=True)

# Set the chart title and labels
plt.title('Hospitalization Rates by Risk Category and Illness State')
plt.xlabel('Illness State')
plt.ylabel('Hospitalization Rate')

# Display the chart
plt.show()

# %% [markdown]
# #### Visualization: What is the correlation between various factors related to foodborne illnesses?

# %%
# Read the data into a Pandas DataFrame
df = pd.read_csv('food data merged.csv')

# Compute the correlation matrix
corr = df.corr()

plt.figure(figsize=(20, 18))

# Visualize the correlation matrix using a heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
